# %% [markdown]
# <a href="https://colab.research.google.com/github/hsh6449/TIL/blob/main/pytorch/torch_7_5_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## #1 로지스틱 회귀
# - 시그모이드 함수
# - $sigmoid(x) = \frac{1}{1+e^-(Wx+b)}$

# %%
def sigmoid(x):
  return 1/(1+np.exp(-x))

# %%
x = np.arange(-5.0,5.0,0.1)
y = sigmoid(x)

# %%
plt.plot(x,y,'-g')
plt.plot([0,0],[1.0,0.0],':')
plt.title('sigmoid plot')
# Out:
# Text(0.5, 1.0, 'sigmoid plot')

# %%
# W값 변화에 따른 모양

y1 = sigmoid(0.5*x)
y2 = sigmoid(x)
y3 = sigmoid(2*x)

plt.plot(x,y1,'b')
plt.plot(x,y2,'g')
plt.plot(x,y3,'r')
plt.plot([0,0],[1.0,0.0],':')
plt.title('sigmoid plot')
# Out:
# Text(0.5, 1.0, 'sigmoid plot')

# %%
# b값 변화에 따른 모양

y1 = sigmoid(-2+x)
y2 = sigmoid(x)
y3 = sigmoid(2+x)

plt.plot(x,y1,'--b')
plt.plot(x,y2,'g')
plt.plot(x,y3,'--r')
plt.plot([0,0],[1.0,0.0],':')
plt.title('sigmoid plot')
# Out:
# Text(0.5, 1.0, 'sigmoid plot')

# %% [markdown]
# ## #2 로지스틱 회귀 파이토치로 구현

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %%
torch.manual_seed(1)

# %%
x_data = [[1,2],[2,4],[3,1],[4,3],[5,3],[6,2]]
y_data = [[0],[0],[0],[1],[1],[1]]

# %%
x_train = torch.FloatTensor(x_data)
y_train = torch.FloatTensor(y_data)

# %%
x_train.shape, y_train.shape
# Out:
# (torch.Size([6, 2]), torch.Size([6, 1]))

# %%
W = torch.zeros((2,1), requires_grad=True)
b = torch.zeros(1, requires_grad=True)

# %%
hypothesis = 1/(1+torch.exp(-(x_train.matmul(W)+b))) #or torch.sigmoid(x_train.matmul(W)+b)

# %%
hypothesis
# Out:
# tensor([[0.5000],
#         [0.5000],
#         [0.5000],
#         [0.5000],
#         [0.5000],
#         [0.5000]], grad_fn=<MulBackward0>)

# %%
-(y_train[0] * torch.log(hypothesis[0]) + 
  (1 - y_train[0]) * torch.log(1 - hypothesis[0]))
# Out:
# tensor([0.6931], grad_fn=<NegBackward0>)

# %%
losses = -(y_train * torch.log(hypothesis) + (1 - y_train)*torch.log(1-hypothesis))

losses
# Out:
# tensor([[0.6931],
#         [0.6931],
#         [0.6931],
#         [0.6931],
#         [0.6931],
#         [0.6931]], grad_fn=<NegBackward0>)

# %%
cost = losses.mean()

# %%
cost
# Out:
# tensor(0.6931, grad_fn=<MeanBackward0>)

# %%
F.binary_cross_entropy(hypothesis, y_train)
# Out:
# tensor(0.6931, grad_fn=<BinaryCrossEntropyBackward0>)

# %%
# 훈련과정
x_data = [[1,2],[2,4],[3,1],[4,3],[5,3],[6,2]]
y_data = [[0],[0],[0],[1],[1],[1]]
x_train = torch.FloatTensor(x_data)
y_train = torch.FloatTensor(y_data)

W = torch.zeros((2,1), requires_grad=True)
b = torch.zeros(1, requires_grad=True)

# optimizer
optimizer = optim.SGD([W,b],lr = 1)

epochs = 1000

for epoch in range(epochs+1):
 hypothesis = torch.sigmoid(x_train.matmul(W)+b)
 cost = -(y_train * torch.log(hypothesis) + (1 - y_train)*torch.log(1-hypothesis)).mean()

 optimizer.zero_grad()
 cost.backward()
 optimizer.step()

 if epoch % 100 == 0:
   print("Epoch {:4d}/{} Cost {:.6f}".format(epoch,epochs,cost.item()))
# Out:
# Epoch    0/1000 Cost 0.693147
# Epoch  100/1000 Cost 0.150459
# Epoch  200/1000 Cost 0.094799
# Epoch  300/1000 Cost 0.069868
# Epoch  400/1000 Cost 0.055470
# Epoch  500/1000 Cost 0.046038
# Epoch  600/1000 Cost 0.039361
# Epoch  700/1000 Cost 0.034379
# Epoch  800/1000 Cost 0.030517
# Epoch  900/1000 Cost 0.027434
# Epoch 1000/1000 Cost 0.024915

# %%
W, b
# Out:
# (tensor([[3.6442],
#          [0.9785]], requires_grad=True),
#  tensor([-14.7092], requires_grad=True))

# %%
hypothesis
# Out:
# tensor([[1.1108e-04],
#         [2.9146e-02],
#         [5.7477e-02],
#         [9.4279e-01],
#         [9.9841e-01],
#         [9.9989e-01]], grad_fn=<SigmoidBackward0>)

# %%
prediction = hypothesis >= torch.FloatTensor([0.5])
print(prediction)
# Out:
# tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])

# %% [markdown]
# ## #3 nn모듈로 로지스틱 회귀

# %%
model = nn.Sequential(
    nn.Linear(2,1),
    nn.Sigmoid()
)

# %%
model(x_train)
# Out:
# tensor([[0.3600],
#         [0.1715],
#         [0.6801],
#         [0.4389],
#         [0.5216],
#         [0.7473]], grad_fn=<SigmoidBackward0>)

# %%
optimizer = optim.SGD(model.parameters(), lr = 0.1)

for epoch in range(epochs + 1):
  hypothesis = model(x_train)

  cost = F.binary_cross_entropy(hypothesis, y_train)

  optimizer.zero_grad()
  cost.backward()
  optimizer.step()
  
  if epoch % 10 == 0:
    prediction = hypothesis >= torch.FloatTensor([0.5]) # 예측값이 0.5를 넘으면 True로 간주
    correct_prediction = prediction.float() == y_train # 실제값과 일치하는 경우만 True로 간주
    accuracy = correct_prediction.sum().item() / len(correct_prediction) # 정확도를 계산
    print('Epoch {:4d}/{} Cost: {:.6f} Accuracy {:2.2f}%'.format( # 각 에포크마다 정확도를 출력
        epoch, epochs, cost.item(), accuracy * 100))
# Out:
# Epoch    0/1000 Cost: 0.589938 Accuracy 66.67%
# Epoch   10/1000 Cost: 0.528998 Accuracy 83.33%
# Epoch   20/1000 Cost: 0.513680 Accuracy 83.33%
# Epoch   30/1000 Cost: 0.501084 Accuracy 83.33%
# Epoch   40/1000 Cost: 0.490159 Accuracy 83.33%
# Epoch   50/1000 Cost: 0.480324 Accuracy 83.33%
# Epoch   60/1000 Cost: 0.471241 Accuracy 83.33%
# Epoch   70/1000 Cost: 0.462707 Accuracy 83.33%
# Epoch   80/1000 Cost: 0.454595 Accuracy 83.33%
# Epoch   90/1000 Cost: 0.446822 Accuracy 83.33%
# Epoch  100/1000 Cost: 0.439335 Accuracy 83.33%
# Epoch  110/1000 Cost: 0.432097 Accuracy 83.33%
# Epoch  120/1000 Cost: 0.425082 Accuracy 83.33%
# Epoch  130/1000 Cost: 0.418272 Accuracy 83.33%
# Epoch  140/1000 Cost: 0.411653 Accuracy 83.33%
# Epoch  150/1000 Cost: 0.405214 Accuracy 83.33%
# Epoch  160/1000 Cost: 0.398947 Accuracy 83.33%
# Epoch  170/1000 Cost: 0.392845 Accuracy 83.33%
# Epoch  180/1000 Cost: 0.386902 Accuracy 83.33%
# Epoch  190/1000 Cost: 0.381112 Accuracy 83.33%
# Epoch  200/1000 Cost: 0.375471 Accuracy 83.33%
# Epoch  210/1000 Cost: 0.369973 Accuracy 83.33%
# Epoch  220/1000 Cost: 0.364615 Accuracy 83.33%
# Epoch  230/1000 Cost: 0.359393 Accuracy 83.33%
# Epoch  240/1000 Cost: 0.354301 Accuracy 83.33%
# Epoch  250/1000 Cost: 0.349337 Accuracy 83.33%
# Epoch  260/1000 Cost: 0.344497 Accuracy 83.33%
# Epoch  270/1000 Cost: 0.339777 Accuracy 83.33%
# Epoch  280/1000 Cost: 0.335173 Accuracy 83.33%
# Epoch  290/1000 Cost: 0.330682 Accuracy 83.33%
# Epoch  300/1000 Cost: 0.326301 Accuracy 83.33%
# Epoch  310/1000 Cost: 0.322026 Accuracy 83.33%
# Epoch  320/1000 Cost: 0.317854 Accuracy 83.33%
# Epoch  330/1000 Cost: 0.313782 Accuracy 83.33%
# Epoch  340/1000 Cost: 0.309808 Accuracy 83.33%
# Epoch  350/1000 Cost: 0.305927 Accuracy 83.33%
# Epoch  360/1000 Cost: 0.302138 Accuracy 83.33%
# Epoch  370/1000 Cost: 0.298437 Accuracy 83.33%
# Epoch  380/1000 Cost: 0.294823 Accuracy 83.33%
# Epoch  390/1000 Cost: 0.291291 Accuracy 83.33%
# Epoch  400/1000 Cost: 0.287841 Accuracy 83.33%
# Epoch  410/1000 Cost: 0.284468 Accuracy 83.33%
# Epoch  420/1000 Cost: 0.281172 Accuracy 83.33%
# Epoch  430/1000 Cost: 0.277949 Accuracy 83.33%
# Epoch  440/1000 Cost: 0.274798 Accuracy 83.33%
# Epoch  450/1000 Cost: 0.271717 Accuracy 83.33%
# Epoch  460/1000 Cost: 0.268703 Accuracy 83.33%
# Epoch  470/1000 Cost: 0.265754 Accuracy 83.33%
# Epoch  480/1000 Cost: 0.262868 Accuracy 83.33%
# Epoch  490/1000 Cost: 0.260044 Accuracy 83.33%
# Epoch  500/1000 Cost: 0.257280 Accuracy 83.33%
# Epoch  510/1000 Cost: 0.254575 Accuracy 83.33%
# Epoch  520/1000 Cost: 0.251925 Accuracy 83.33%
# Epoch  530/1000 Cost: 0.249330 Accuracy 83.33%
# Epoch  540/1000 Cost: 0.246789 Accuracy 83.33%
# Epoch  550/1000 Cost: 0.244299 Accuracy 83.33%
# Epoch  560/1000 Cost: 0.241859 Accuracy 83.33%
# Epoch  570/1000 Cost: 0.239468 Accuracy 83.33%
# Epoch  580/1000 Cost: 0.237125 Accuracy 83.33%
# Epoch  590/1000 Cost: 0.234828 Accuracy 100.00%
# Epoch  600/1000 Cost: 0.232575 Accuracy 100.00%
# Epoch  610/1000 Cost: 0.230366 Accuracy 100.00%
# Epoch  620/1000 Cost: 0.228200 Accuracy 100.00%
# Epoch  630/1000 Cost: 0.226074 Accuracy 100.00%
# Epoch  640/1000 Cost: 0.223989 Accuracy 100.00%
# Epoch  650/1000 Cost: 0.221943 Accuracy 100.00%
# Epoch  660/1000 Cost: 0.219935 Accuracy 100.00%
# Epoch  670/1000 Cost: 0.217964 Accuracy 100.00%
# Epoch  680/1000 Cost: 0.216029 Accuracy 100.00%
# Epoch  690/1000 Cost: 0.214129 Accuracy 100.00%
# Epoch  700/1000 Cost: 0.212263 Accuracy 100.00%
# Epoch  710/1000 Cost: 0.210431 Accuracy 100.00%
# Epoch  720/1000 Cost: 0.208631 Accuracy 100.00%
# Epoch  730/1000 Cost: 0.206862 Accuracy 100.00%
# Epoch  740/1000 Cost: 0.205124 Accuracy 100.00%
# Epoch  750/1000 Cost: 0.203417 Accuracy 100.00%
# Epoch  760/1000 Cost: 0.201738 Accuracy 100.00%
# Epoch  770/1000 Cost: 0.200088 Accuracy 100.00%
# Epoch  780/1000 Cost: 0.198466 Accuracy 100.00%
# Epoch  790/1000 Cost: 0.196871 Accuracy 100.00%
# Epoch  800/1000 Cost: 0.195302 Accuracy 100.00%
# Epoch  810/1000 Cost: 0.193759 Accuracy 100.00%
# Epoch  820/1000 Cost: 0.192242 Accuracy 100.00%
# Epoch  830/1000 Cost: 0.190749 Accuracy 100.00%
# Epoch  840/1000 Cost: 0.189279 Accuracy 100.00%
# Epoch  850/1000 Cost: 0.187834 Accuracy 100.00%
# Epoch  860/1000 Cost: 0.186411 Accuracy 100.00%
# Epoch  870/1000 Cost: 0.185011 Accuracy 100.00%
# Epoch  880/1000 Cost: 0.183632 Accuracy 100.00%
# Epoch  890/1000 Cost: 0.182275 Accuracy 100.00%
# Epoch  900/1000 Cost: 0.180939 Accuracy 100.00%
# Epoch  910/1000 Cost: 0.179623 Accuracy 100.00%
# Epoch  920/1000 Cost: 0.178327 Accuracy 100.00%
# Epoch  930/1000 Cost: 0.177050 Accuracy 100.00%
# Epoch  940/1000 Cost: 0.175792 Accuracy 100.00%
# Epoch  950/1000 Cost: 0.174553 Accuracy 100.00%
# Epoch  960/1000 Cost: 0.173333 Accuracy 100.00%
# Epoch  970/1000 Cost: 0.172130 Accuracy 100.00%
# Epoch  980/1000 Cost: 0.170944 Accuracy 100.00%
# Epoch  990/1000 Cost: 0.169775 Accuracy 100.00%
# Epoch 1000/1000 Cost: 0.168623 Accuracy 100.00%

# %%
model(x_train)
# Out:
# tensor([[0.0294],
#         [0.1339],
#         [0.3698],
#         [0.7499],
#         [0.9315],
#         [0.9831]], grad_fn=<SigmoidBackward0>)

# %% [markdown]
# - 로지스틱 회귀는 인공신경망으로 간주가능

# %% [markdown]
# ## #4 Class로 구현
#
# - __init__()에서 모델의 구조와 동적을 정의하는 생성자를 정의합니다. 이는 파이썬에서 객체가 갖는 속성값을 초기화하는 역할로, 객체가 생성될 때 자동으로 호출
# - self가 있으면 자동으로 되는듯?

# %%
class BinaryC(nn.Module) :
  def __init__(self):
    super().__init__()
    self.linear = nn.Linear(2,1)
    self.sigmoid = nn.Sigmoid()

  def forward(self,x):
    return self.sigmoid(self.linear(x))

# %%
model = BinaryC()

# %%
# optimizer 설정
optimizer = optim.SGD(model.parameters(), lr=1)

nb_epochs = 1000
for epoch in range(nb_epochs + 1):

    # H(x) 계산
    hypothesis = model(x_train)

    # cost 계산
    cost = F.binary_cross_entropy(hypothesis, y_train)

    # cost로 H(x) 개선
    optimizer.zero_grad()
    cost.backward()
    optimizer.step()

    # 20번마다 로그 출력
    if epoch % 10 == 0:
        prediction = hypothesis >= torch.FloatTensor([0.5]) # 예측값이 0.5를 넘으면 True로 간주
        correct_prediction = prediction.float() == y_train # 실제값과 일치하는 경우만 True로 간주
        accuracy = correct_prediction.sum().item() / len(correct_prediction) # 정확도를 계산
        print('Epoch {:4d}/{} Cost: {:.6f} Accuracy {:2.2f}%'.format( # 각 에포크마다 정확도를 출력
            epoch, nb_epochs, cost.item(), accuracy * 100,
        ))
# Out:
# Epoch    0/1000 Cost: 0.755238 Accuracy 50.00%
# Epoch   10/1000 Cost: 0.633863 Accuracy 83.33%
# Epoch   20/1000 Cost: 0.563394 Accuracy 83.33%
# Epoch   30/1000 Cost: 0.477787 Accuracy 83.33%
# Epoch   40/1000 Cost: 0.410422 Accuracy 83.33%
# Epoch   50/1000 Cost: 0.347525 Accuracy 83.33%
# Epoch   60/1000 Cost: 0.288665 Accuracy 83.33%
# Epoch   70/1000 Cost: 0.235669 Accuracy 83.33%
# Epoch   80/1000 Cost: 0.192692 Accuracy 83.33%
# Epoch   90/1000 Cost: 0.164762 Accuracy 100.00%
# Epoch  100/1000 Cost: 0.150438 Accuracy 100.00%
# Epoch  110/1000 Cost: 0.141570 Accuracy 100.00%
# Epoch  120/1000 Cost: 0.134069 Accuracy 100.00%
# Epoch  130/1000 Cost: 0.127367 Accuracy 100.00%
# Epoch  140/1000 Cost: 0.121334 Accuracy 100.00%
# Epoch  150/1000 Cost: 0.115872 Accuracy 100.00%
# Epoch  160/1000 Cost: 0.110903 Accuracy 100.00%
# Epoch  170/1000 Cost: 0.106359 Accuracy 100.00%
# Epoch  180/1000 Cost: 0.102189 Accuracy 100.00%
# Epoch  190/1000 Cost: 0.098346 Accuracy 100.00%
# Epoch  200/1000 Cost: 0.094792 Accuracy 100.00%
# Epoch  210/1000 Cost: 0.091496 Accuracy 100.00%
# Epoch  220/1000 Cost: 0.088429 Accuracy 100.00%
# Epoch  230/1000 Cost: 0.085568 Accuracy 100.00%
# Epoch  240/1000 Cost: 0.082892 Accuracy 100.00%
# Epoch  250/1000 Cost: 0.080383 Accuracy 100.00%
# Epoch  260/1000 Cost: 0.078026 Accuracy 100.00%
# Epoch  270/1000 Cost: 0.075807 Accuracy 100.00%
# Epoch  280/1000 Cost: 0.073714 Accuracy 100.00%
# Epoch  290/1000 Cost: 0.071736 Accuracy 100.00%
# Epoch  300/1000 Cost: 0.069864 Accuracy 100.00%
# Epoch  310/1000 Cost: 0.068089 Accuracy 100.00%
# Epoch  320/1000 Cost: 0.066405 Accuracy 100.00%
# Epoch  330/1000 Cost: 0.064803 Accuracy 100.00%
# Epoch  340/1000 Cost: 0.063278 Accuracy 100.00%
# Epoch  350/1000 Cost: 0.061824 Accuracy 100.00%
# Epoch  360/1000 Cost: 0.060437 Accuracy 100.00%
# Epoch  370/1000 Cost: 0.059112 Accuracy 100.00%
# Epoch  380/1000 Cost: 0.057844 Accuracy 100.00%
# Epoch  390/1000 Cost: 0.056631 Accuracy 100.00%
# Epoch  400/1000 Cost: 0.055468 Accuracy 100.00%
# Epoch  410/1000 Cost: 0.054352 Accuracy 100.00%
# Epoch  420/1000 Cost: 0.053281 Accuracy 100.00%
# Epoch  430/1000 Cost: 0.052252 Accuracy 100.00%
# Epoch  440/1000 Cost: 0.051262 Accuracy 100.00%
# Epoch  450/1000 Cost: 0.050309 Accuracy 100.00%
# Epoch  460/1000 Cost: 0.049392 Accuracy 100.00%
# Epoch  470/1000 Cost: 0.048507 Accuracy 100.00%
# Epoch  480/1000 Cost: 0.047654 Accuracy 100.00%
# Epoch  490/1000 Cost: 0.046831 Accuracy 100.00%
# Epoch  500/1000 Cost: 0.046036 Accuracy 100.00%
# Epoch  510/1000 Cost: 0.045268 Accuracy 100.00%
# Epoch  520/1000 Cost: 0.044524 Accuracy 100.00%
# Epoch  530/1000 Cost: 0.043806 Accuracy 100.00%
# Epoch  540/1000 Cost: 0.043110 Accuracy 100.00%
# Epoch  550/1000 Cost: 0.042436 Accuracy 100.00%
# Epoch  560/1000 Cost: 0.041782 Accuracy 100.00%
# Epoch  570/1000 Cost: 0.041149 Accuracy 100.00%
# Epoch  580/1000 Cost: 0.040535 Accuracy 100.00%
# Epoch  590/1000 Cost: 0.039938 Accuracy 100.00%
# Epoch  600/1000 Cost: 0.039360 Accuracy 100.00%
# Epoch  610/1000 Cost: 0.038797 Accuracy 100.00%
# Epoch  620/1000 Cost: 0.038251 Accuracy 100.00%
# Epoch  630/1000 Cost: 0.037720 Accuracy 100.00%
# Epoch  640/1000 Cost: 0.037203 Accuracy 100.00%
# Epoch  650/1000 Cost: 0.036700 Accuracy 100.00%
# Epoch  660/1000 Cost: 0.036211 Accuracy 100.00%
# Epoch  670/1000 Cost: 0.035735 Accuracy 100.00%
# Epoch  680/1000 Cost: 0.035271 Accuracy 100.00%
# Epoch  690/1000 Cost: 0.034819 Accuracy 100.00%
# Epoch  700/1000 Cost: 0.034378 Accuracy 100.00%
# Epoch  710/1000 Cost: 0.033948 Accuracy 100.00%
# Epoch  720/1000 Cost: 0.033529 Accuracy 100.00%
# Epoch  730/1000 Cost: 0.033121 Accuracy 100.00%
# Epoch  740/1000 Cost: 0.032722 Accuracy 100.00%
# Epoch  750/1000 Cost: 0.032332 Accuracy 100.00%
# Epoch  760/1000 Cost: 0.031952 Accuracy 100.00%
# Epoch  770/1000 Cost: 0.031580 Accuracy 100.00%
# Epoch  780/1000 Cost: 0.031217 Accuracy 100.00%
# Epoch  790/1000 Cost: 0.030863 Accuracy 100.00%
# Epoch  800/1000 Cost: 0.030516 Accuracy 100.00%
# Epoch  810/1000 Cost: 0.030177 Accuracy 100.00%
# Epoch  820/1000 Cost: 0.029845 Accuracy 100.00%
# Epoch  830/1000 Cost: 0.029521 Accuracy 100.00%
# Epoch  840/1000 Cost: 0.029203 Accuracy 100.00%
# Epoch  850/1000 Cost: 0.028893 Accuracy 100.00%
# Epoch  860/1000 Cost: 0.028589 Accuracy 100.00%
# Epoch  870/1000 Cost: 0.028291 Accuracy 100.00%
# Epoch  880/1000 Cost: 0.027999 Accuracy 100.00%
# Epoch  890/1000 Cost: 0.027713 Accuracy 100.00%
# Epoch  900/1000 Cost: 0.027433 Accuracy 100.00%
# Epoch  910/1000 Cost: 0.027159 Accuracy 100.00%
# Epoch  920/1000 Cost: 0.026890 Accuracy 100.00%
# Epoch  930/1000 Cost: 0.026626 Accuracy 100.00%
# Epoch  940/1000 Cost: 0.026367 Accuracy 100.00%
# Epoch  950/1000 Cost: 0.026114 Accuracy 100.00%
# Epoch  960/1000 Cost: 0.025865 Accuracy 100.00%
# Epoch  970/1000 Cost: 0.025620 Accuracy 100.00%
# Epoch  980/1000 Cost: 0.025381 Accuracy 100.00%
# Epoch  990/1000 Cost: 0.025146 Accuracy 100.00%
# Epoch 1000/1000 Cost: 0.024915 Accuracy 100.00%
